# %% [markdown]
# ### In this notebook we will concatenate all the datasets from year 2014 to 2020 along the dimension of time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import xarray as xr

# %%
path = "/content/drive/MyDrive/Lightning/data/pre-processed data/data20*.nc"
ds = xr.open_mfdataset(path, parallel=True, concat_dim="time", combine="nested")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 29, level: 16, longitude: 33, time: 10248)
# Coordinates:
#   * longitude  (longitude) float32 73.0 73.25 73.5 73.75 ... 80.5 80.75 81.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 15.5 15.25 15.0
#   * level      (level) int32 500 550 600 650 700 750 ... 900 925 950 975 1000
#   * time       (time) datetime64[ns] 2014-04-01 ... 2020-05-31T23:00:00
# Data variables:
#     r          (time, level, latitude, longitude) float32 dask.array<chunksize=(1464, 16, 29, 33), meta=np.ndarray>
#     clwc       (time, level, latitude, longitude) float32 dask.array<chunksize=(1464, 16, 29, 33), meta=np.ndarray>
#     t          (time, level, latitude, longitude) float32 dask.array<chunksize=(1464, 16, 29, 33), meta=np.ndarray>
#     w          (time, level, latitude, longitude) float32 dask.array<chunksize=(1464, 16, 29, 33), meta=np.ndarray>
# ...

# %%
ds.to_netcdf("/content/drive/MyDrive/Lightning/data/pre-processed data/BinaryLightningData.nc")
