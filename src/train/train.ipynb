# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/Lightning/notebooks/model'
# Out:
# /content/drive/MyDrive/Lightning/notebooks/model

# %% [markdown]
# ### Importing essential libraries

# %%
from config import CONFIG
import xarray as xr
import numpy as np
from sklearn.preprocessing import StandardScaler
from Lightning_Binary_Classifier import LSTM_Conv2D_KDD
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras import callbacks

# %%
channels = CONFIG["FEATURES_NAMES"]
ds_path = CONFIG["COMBINED_PATH"]
step = 6

# %% [markdown]
# ### Creating method to structure meteorological data with 6 hour step time

# %%
def preprocess_data(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		end_ix = i + n_steps
		if end_ix > len(sequence)-1 or end_ix+6 > len(sequence)-1:
			break
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:end_ix+6]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %% [markdown]
# ### Creating method to structure lightning data with 3 hour step time

# %%
def preprocess_data_2(sequence, n_steps):
	X = list()
	for i in range(len(sequence)):
		end_ix = i + n_steps
		if end_ix > len(sequence)-1 or end_ix+6 > len(sequence)-1:
			break
		seq_x = sequence[i:i+3]
		X.append(seq_x)
	return np.array(X)

# %%
train_df = xr.open_dataset(ds_path).sel(time=slice("2015", "2018"))
val_df = xr.open_dataset(ds_path).sel(time=slice("2019", "2020"))

# %%
dataset={}
norm={}
for i in channels:
  if i == 'r':
    temp=train_df[i].values[:,0,:,:]
  else:
    temp=train_df[i].values
  scalers = {}
  for j in range(temp.shape[1]):
    scalers[j] = StandardScaler()
    temp[:, j, :] = scalers[j].fit_transform(temp[:, j, :]) 
  dataset[i]=temp
  norm[i]=scalers
  print(i)
# Out:
# p80.162
# p79.162
# cape
# r

# %%
def create_input(channels, ds_path, n_steps):
	stack = []
	for i in channels:
		input, _ = preprocess_data(dataset[i], n_steps=step)
		print(f"Adding channel {i} with shape: {input.shape}")
		stack.append(input)
	out = np.stack(stack, axis=-1)
	return out

# %%
train_input1 = create_input(channels, ds_path, step)


#Encoder-2 Input 
train_input2 = preprocess_data_2(train_df['Amplitude'].values, n_steps=step)
train_input2 = np.expand_dims(train_input2, axis=-1) 

temp,_ = preprocess_data(train_df['Amplitude'].values, n_steps=step)
train_input3 = temp[:,5,:,:]
train_input3 = np.expand_dims(train_input3, axis=1)

#Decoder Output
_, train_target = preprocess_data(train_df['Amplitude'].values, n_steps=step)
train_target = np.expand_dims(train_target, axis=-1)
train_target = np.reshape(train_target, (-1,6, 29 * 33, 1))
# Out:
# Adding channel p80.162 with shape: (5844, 6, 29, 33)
# Adding channel p79.162 with shape: (5844, 6, 29, 33)
# Adding channel cape with shape: (5844, 6, 29, 33)
# Adding channel r with shape: (5844, 6, 29, 33)

# %% [markdown]
# ### Viewing the training input shape.

# %%
print(train_input1.shape)
print(train_input2.shape)
print(train_input3.shape)
print(train_target.shape)
# Out:
# (5844, 6, 29, 33, 4)
# (5844, 3, 29, 33, 1)
# (5844, 1, 29, 33)
# (5844, 6, 957, 1)

# %%
#Validation Data
for i in channels:
  if i == 'r':
    temp=val_df[i].values[:,0,:,:]
  else:  
    temp=val_df[i].values
  scalers = {}
  for j in range(temp.shape[1]):
    scalers[j] = StandardScaler()
    temp[:, j, :] = scalers[j].fit_transform(temp[:, j, :]) 
  dataset[i]=temp
  norm[i]=scalers
  print(i)
# Out:
# p80.162
# p79.162
# cape
# r

# %%
#Encoder-1 Input
def create_input(channels, ds_path, n_steps):
	stack = []
	for i in channels:
		input, _ = preprocess_data(dataset[i], n_steps=step)
		print(f"Adding channel {i} with shape: {input.shape}")
		stack.append(input)
	out = np.stack(stack, axis=-1)
	return out

# %%
val_input1 = create_input(channels, ds_path, step)

#Encoder-2 Input 
val_input2 = preprocess_data_2(val_df['Amplitude'].values, n_steps=step)
val_input2 = np.expand_dims(val_input2, axis=-1) 

temp,_ = preprocess_data(val_df['Amplitude'].values, n_steps=step)
val_input3 = temp[:,5,:,:]
val_input3 = np.expand_dims(val_input3, axis=1)

#Decoder Output
_, val_target = preprocess_data(val_df['Amplitude'].values, n_steps=step)
val_target = np.expand_dims(val_target, axis=-1)
val_target = np.reshape(val_target, (-1,6, 29 * 33, 1))
# Out:
# Adding channel p80.162 with shape: (2916, 6, 29, 33)
# Adding channel p79.162 with shape: (2916, 6, 29, 33)
# Adding channel cape with shape: (2916, 6, 29, 33)
# Adding channel r with shape: (2916, 6, 29, 33)

# %% [markdown]
# ### Viewing the validation data shape.

# %%
print(val_input1.shape)
print(val_input2.shape)
print(val_input3.shape)
print(val_target.shape)
# Out:
# (2916, 6, 29, 33, 4)
# (2916, 3, 29, 33, 1)
# (2916, 1, 29, 33)
# (2916, 6, 957, 1)

# %%
train_data_X = [train_input1 ,train_input2 ,train_input3]
val_data_X   = [val_input1 ,val_input2 ,val_input3]

train_data_Y = train_target
val_data_Y = val_target

model = LSTM_Conv2D_KDD()

# %% [markdown]
# ### Summary of the model being used

# %%
model.summary()
# Out:
# Model: "ConvLSTM-Conv2d-KDD"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder1_inputs (InputLayer)   [(None, None, 29, 3  0           []
#                                 3, 4)]
#
#  encoder2_inputs (InputLayer)   [(None, None, 29, 3  0           []
#                                 3, 1)]
#
#  en1_conv2d (TimeDistributed)   (None, None, 15, 17  12608       ['encoder1_inputs[0][0]']
#                                 , 64)
#
#  en2_conv2d (TimeDistributed)   (None, None, 15, 17  200         ['encoder2_inputs[0][0]']
#                                 , 4)
#
#  time_distributed (TimeDistribu  (None, None, 15, 17  0          ['en1_conv2d[0][0]']
#  ted)                           , 64)
#
#  time_distributed_1 (TimeDistri  (None, None, 15, 17  0          ['en2_conv2d[0][0]']
#  buted)                         , 4)
#
#  decoder_inputs (InputLayer)    [(None, None, 29, 3  0           []
#                                 3, 1)]
#
#  en1_convlstm (ConvLSTM2D)      [(None, None, 15, 1  2458112     ['time_distributed[0][0]']
#                                 7, 128),
#                                  (None, 15, 17, 128
#                                 ),
#                                  (None, 15, 17, 128
#                                 )]
#
#  en2_convlstm (ConvLSTM2D)      [(None, None, 15, 1  9632        ['time_distributed_1[0][0]']
#                                 7, 8),
#                                  (None, 15, 17, 8),
#                                  (None, 15, 17, 8)]
#
#  de_conv2d (TimeDistributed)    (None, None, 15, 17  200         ['decoder_inputs[0][0]',
#                                 , 4)                              'activation_3[0][0]',
#                                                                   'activation_3[1][0]',
#                                                                   'activation_3[2][0]',
#                                                                   'activation_3[3][0]',
#                                                                   'activation_3[4][0]']
#
#  concatenate (Concatenate)      (None, 15, 17, 136)  0           ['en1_convlstm[0][1]',
#                                                                   'en2_convlstm[0][1]']
#
#  concatenate_1 (Concatenate)    (None, 15, 17, 136)  0           ['en1_convlstm[0][2]',
#                                                                   'en2_convlstm[0][2]']
#
#  activation_2 (Activation)      multiple             0           ['de_conv2d[0][0]',
#                                                                   'de_conv2dT[0][0]',
#                                                                   'de_conv2d[1][0]',
#                                                                   'de_conv2dT[1][0]',
#                                                                   'de_conv2d[2][0]',
#                                                                   'de_conv2dT[2][0]',
#                                                                   'de_conv2d[3][0]',
#                                                                   'de_conv2dT[3][0]',
#                                                                   'de_conv2d[4][0]',
#                                                                   'de_conv2dT[4][0]',
#                                                                   'de_conv2d[5][0]',
#                                                                   'de_conv2dT[5][0]']
#
#  h_conv2d (Conv2D)              (None, 15, 17, 64)   8768        ['concatenate[0][0]']
#
#  c_conv2d (Conv2D)              (None, 15, 17, 64)   8768        ['concatenate_1[0][0]']
#
#  de_convlstm (ConvLSTM2D)       [(None, None, 15, 1  435456      ['activation_2[0][0]',
#                                 7, 64),                           'h_conv2d[0][0]',
#                                  (None, 15, 17, 64)               'c_conv2d[0][0]',
#                                 , (None, 15, 17, 64               'activation_2[2][0]',
#                                 )]                                'de_convlstm[0][1]',
#                                                                   'de_convlstm[0][2]',
#                                                                   'activation_2[4][0]',
#                                                                   'de_convlstm[1][1]',
#                                                                   'de_convlstm[1][2]',
#                                                                   'activation_2[6][0]',
#                                                                   'de_convlstm[2][1]',
#                                                                   'de_convlstm[2][2]',
#                                                                   'activation_2[8][0]',
#                                                                   'de_convlstm[3][1]',
#                                                                   'de_convlstm[3][2]',
#                                                                   'activation_2[10][0]',
#                                                                   'de_convlstm[4][1]',
#                                                                   'de_convlstm[4][2]']
#
#  de_conv2dT (TimeDistributed)   (None, None, 30, 34  200768      ['de_convlstm[0][0]',
#                                 , 64)                             'de_convlstm[1][0]',
#                                                                   'de_convlstm[2][0]',
#                                                                   'de_convlstm[3][0]',
#                                                                   'de_convlstm[4][0]',
#                                                                   'de_convlstm[5][0]']
#
#  de_out_conv2d (TimeDistributed  (None, None, 30, 34  65         ['activation_2[1][0]',
#  )                              , 1)                              'activation_2[3][0]',
#                                                                   'activation_2[5][0]',
#                                                                   'activation_2[7][0]',
#                                                                   'activation_2[9][0]',
#                                                                   'activation_2[11][0]']
#
#  cropping3d (Cropping3D)        (None, None, 29, 33  0           ['de_out_conv2d[0][0]',
#                                 , 1)                              'de_out_conv2d[1][0]',
#                                                                   'de_out_conv2d[2][0]',
#                                                                   'de_out_conv2d[3][0]',
#                                                                   'de_out_conv2d[4][0]',
#                                                                   'de_out_conv2d[5][0]']
#
#  activation_3 (Activation)      (None, None, 29, 33  0           ['cropping3d[0][0]',
#                                 , 1)                              'cropping3d[1][0]',
#                                                                   'cropping3d[2][0]',
#                                                                   'cropping3d[3][0]',
#                                                                   'cropping3d[4][0]']
#
#  lambda (Lambda)                (None, None, 29, 33  0           ['cropping3d[0][0]',
#                                 , 1)                              'cropping3d[1][0]',
#                                                                   'cropping3d[2][0]',
#                                                                   'cropping3d[3][0]',
#                                                                   'cropping3d[4][0]',
#                                                                   'cropping3d[5][0]']
#
#  reshape (Reshape)              (None, None, 957, 1  0           ['lambda[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 3,134,577
# Trainable params: 3,134,577
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Defing the metrics

# %%
#Metrics
def POD(y_true, y_pred):
    ytrue = y_true
    ypred = K.sigmoid(y_pred)
    ypred = K.round(ypred)
    true_positives = K.sum(ytrue * ypred)
    possible_positives = K.sum(ytrue)
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def FAR(y_true, y_pred):
    ytrue = y_true
    ypred = K.sigmoid(y_pred)
    ypred = K.round(ypred)
    true_positives = K.sum(ytrue * ypred)
    predicted_positives = K.sum(ypred)
    precision = true_positives / (predicted_positives + K.epsilon())
    return 1 - precision

def binary_acc(y_true,y_pred):
    ypred = K.sigmoid(y_pred)
    return K.mean(K.equal(y_true, K.round(ypred)), axis=-1)

# %% [markdown]
# ### Defing the loss function

# %%
def weight_loss(y_true,y_pred):  # binary classification
    pw = 4
    ytrue = K.flatten(y_true)
    ypred = K.flatten(y_pred)
    return tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(logits=ypred,labels=ytrue,pos_weight=pw))

# %% [markdown]
# ### Compiling the model

# %%
adam = optimizers.Adam(lr=0.0001)
model.compile(loss = weight_loss,optimizer = adam, metrics=[POD,FAR,binary_acc])

logdir = "/content/drive/MyDrive/Lightning/logs"
call1 = callbacks.TensorBoard(log_dir=logdir, histogram_freq=10, write_graph=True)

modelfileDir="/content/drive/MyDrive/Lightning/saved models"
call2 = callbacks.ModelCheckpoint(modelfileDir, monitor='val_FAR', verbose=1, save_best_only=True, mode='min', save_weights_only=False)

call3 = callbacks.ReduceLROnPlateau()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ### Training the model

# %%
model.fit(
x=train_data_X,
y=train_data_Y,
validation_data=(val_data_X,val_data_Y),
epochs=50,
batch_size=8,
shuffle=False,
callbacks=[call1,call2,call3],
)
# Out:
# Epoch 1/50
# 731/731 [==============================] - ETA: 0s - loss: 0.3996 - POD: 0.0038 - FAR: 0.9881 - binary_acc: 0.9655
# Epoch 00001: val_FAR improved from inf to 0.93211, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 136s 149ms/step - loss: 0.3996 - POD: 0.0038 - FAR: 0.9881 - binary_acc: 0.9655 - val_loss: 0.2726 - val_POD: 0.0116 - val_FAR: 0.9321 - val_binary_acc: 0.9827 - lr: 1.0000e-04
# Epoch 2/50
# 731/731 [==============================] - ETA: 0s - loss: 0.3194 - POD: 0.0980 - FAR: 0.7921 - binary_acc: 0.9616
# Epoch 00002: val_FAR improved from 0.93211 to 0.90648, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 144ms/step - loss: 0.3194 - POD: 0.0980 - FAR: 0.7921 - binary_acc: 0.9616 - val_loss: 0.1899 - val_POD: 0.1235 - val_FAR: 0.9065 - val_binary_acc: 0.9719 - lr: 1.0000e-04
# Epoch 3/50
# 731/731 [==============================] - ETA: 0s - loss: 0.3005 - POD: 0.1343 - FAR: 0.8042 - binary_acc: 0.9605
# Epoch 00003: val_FAR improved from 0.90648 to 0.88805, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 106s 145ms/step - loss: 0.3005 - POD: 0.1343 - FAR: 0.8042 - binary_acc: 0.9605 - val_loss: 0.1802 - val_POD: 0.1303 - val_FAR: 0.8881 - val_binary_acc: 0.9746 - lr: 1.0000e-04
# Epoch 4/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2905 - POD: 0.1442 - FAR: 0.7924 - binary_acc: 0.9604
# Epoch 00004: val_FAR improved from 0.88805 to 0.87949, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 144ms/step - loss: 0.2905 - POD: 0.1442 - FAR: 0.7924 - binary_acc: 0.9604 - val_loss: 0.1822 - val_POD: 0.1594 - val_FAR: 0.8795 - val_binary_acc: 0.9728 - lr: 1.0000e-04
# Epoch 5/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2839 - POD: 0.1495 - FAR: 0.7832 - binary_acc: 0.9606
# Epoch 00005: val_FAR improved from 0.87949 to 0.86852, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 144ms/step - loss: 0.2839 - POD: 0.1495 - FAR: 0.7832 - binary_acc: 0.9606 - val_loss: 0.1812 - val_POD: 0.1651 - val_FAR: 0.8685 - val_binary_acc: 0.9745 - lr: 1.0000e-04
# Epoch 6/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2777 - POD: 0.1553 - FAR: 0.7765 - binary_acc: 0.9608
# Epoch 00006: val_FAR did not improve from 0.86852
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2777 - POD: 0.1553 - FAR: 0.7765 - binary_acc: 0.9608 - val_loss: 0.1785 - val_POD: 0.1759 - val_FAR: 0.8725 - val_binary_acc: 0.9732 - lr: 1.0000e-04
# Epoch 7/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2717 - POD: 0.1614 - FAR: 0.7744 - binary_acc: 0.9605
# Epoch 00007: val_FAR improved from 0.86852 to 0.86632, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 143ms/step - loss: 0.2717 - POD: 0.1614 - FAR: 0.7744 - binary_acc: 0.9605 - val_loss: 0.1761 - val_POD: 0.1865 - val_FAR: 0.8663 - val_binary_acc: 0.9716 - lr: 1.0000e-04
# Epoch 8/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2673 - POD: 0.1689 - FAR: 0.7691 - binary_acc: 0.9602
# Epoch 00008: val_FAR improved from 0.86632 to 0.86328, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 143ms/step - loss: 0.2673 - POD: 0.1689 - FAR: 0.7691 - binary_acc: 0.9602 - val_loss: 0.1730 - val_POD: 0.1920 - val_FAR: 0.8633 - val_binary_acc: 0.9712 - lr: 1.0000e-04
# Epoch 9/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2628 - POD: 0.1777 - FAR: 0.7656 - binary_acc: 0.9595
# Epoch 00009: val_FAR did not improve from 0.86328
# 731/731 [==============================] - 93s 127ms/step - loss: 0.2628 - POD: 0.1777 - FAR: 0.7656 - binary_acc: 0.9595 - val_loss: 0.1723 - val_POD: 0.2149 - val_FAR: 0.8666 - val_binary_acc: 0.9689 - lr: 1.0000e-04
# Epoch 10/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2586 - POD: 0.1904 - FAR: 0.7615 - binary_acc: 0.9586
# Epoch 00010: val_FAR did not improve from 0.86328
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2586 - POD: 0.1904 - FAR: 0.7615 - binary_acc: 0.9586 - val_loss: 0.1698 - val_POD: 0.2292 - val_FAR: 0.8654 - val_binary_acc: 0.9676 - lr: 1.0000e-04
# Epoch 11/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2544 - POD: 0.2031 - FAR: 0.7609 - binary_acc: 0.9578
# Epoch 00011: val_FAR did not improve from 0.86328
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2544 - POD: 0.2031 - FAR: 0.7609 - binary_acc: 0.9578 - val_loss: 0.1698 - val_POD: 0.2348 - val_FAR: 0.8635 - val_binary_acc: 0.9670 - lr: 1.0000e-04
# Epoch 12/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2498 - POD: 0.2176 - FAR: 0.7548 - binary_acc: 0.9572
# Epoch 00012: val_FAR improved from 0.86328 to 0.85831, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 143ms/step - loss: 0.2498 - POD: 0.2176 - FAR: 0.7548 - binary_acc: 0.9572 - val_loss: 0.1694 - val_POD: 0.2276 - val_FAR: 0.8583 - val_binary_acc: 0.9678 - lr: 1.0000e-04
# Epoch 13/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2452 - POD: 0.2312 - FAR: 0.7513 - binary_acc: 0.9567
# Epoch 00013: val_FAR did not improve from 0.85831
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2452 - POD: 0.2312 - FAR: 0.7513 - binary_acc: 0.9567 - val_loss: 0.1695 - val_POD: 0.2261 - val_FAR: 0.8584 - val_binary_acc: 0.9681 - lr: 1.0000e-04
# Epoch 14/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2409 - POD: 0.2440 - FAR: 0.7446 - binary_acc: 0.9565
# Epoch 00014: val_FAR improved from 0.85831 to 0.85574, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 143ms/step - loss: 0.2409 - POD: 0.2440 - FAR: 0.7446 - binary_acc: 0.9565 - val_loss: 0.1713 - val_POD: 0.2221 - val_FAR: 0.8557 - val_binary_acc: 0.9680 - lr: 1.0000e-04
# Epoch 15/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2361 - POD: 0.2587 - FAR: 0.7411 - binary_acc: 0.9563
# Epoch 00015: val_FAR did not improve from 0.85574
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2361 - POD: 0.2587 - FAR: 0.7411 - binary_acc: 0.9563 - val_loss: 0.1728 - val_POD: 0.1992 - val_FAR: 0.8571 - val_binary_acc: 0.9704 - lr: 1.0000e-04
# Epoch 16/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2306 - POD: 0.2726 - FAR: 0.7321 - binary_acc: 0.9564
# Epoch 00016: val_FAR improved from 0.85574 to 0.85301, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 104s 143ms/step - loss: 0.2306 - POD: 0.2726 - FAR: 0.7321 - binary_acc: 0.9564 - val_loss: 0.1767 - val_POD: 0.1890 - val_FAR: 0.8530 - val_binary_acc: 0.9715 - lr: 1.0000e-04
# Epoch 17/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2249 - POD: 0.2870 - FAR: 0.7275 - binary_acc: 0.9568
# Epoch 00017: val_FAR did not improve from 0.85301
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2249 - POD: 0.2870 - FAR: 0.7275 - binary_acc: 0.9568 - val_loss: 0.1805 - val_POD: 0.1923 - val_FAR: 0.8559 - val_binary_acc: 0.9707 - lr: 1.0000e-04
# Epoch 18/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2196 - POD: 0.3021 - FAR: 0.7253 - binary_acc: 0.9570
# Epoch 00018: val_FAR improved from 0.85301 to 0.84960, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 104s 143ms/step - loss: 0.2196 - POD: 0.3021 - FAR: 0.7253 - binary_acc: 0.9570 - val_loss: 0.1855 - val_POD: 0.1844 - val_FAR: 0.8496 - val_binary_acc: 0.9707 - lr: 1.0000e-04
# Epoch 19/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2152 - POD: 0.3114 - FAR: 0.7190 - binary_acc: 0.9574
# Epoch 00019: val_FAR did not improve from 0.84960
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2152 - POD: 0.3114 - FAR: 0.7190 - binary_acc: 0.9574 - val_loss: 0.1893 - val_POD: 0.1983 - val_FAR: 0.8590 - val_binary_acc: 0.9677 - lr: 1.0000e-04
# Epoch 20/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2119 - POD: 0.3241 - FAR: 0.7155 - binary_acc: 0.9577
# Epoch 00020: val_FAR did not improve from 0.84960
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2119 - POD: 0.3241 - FAR: 0.7155 - binary_acc: 0.9577 - val_loss: 0.1902 - val_POD: 0.2315 - val_FAR: 0.8733 - val_binary_acc: 0.9622 - lr: 1.0000e-04
# Epoch 21/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2082 - POD: 0.3337 - FAR: 0.7148 - binary_acc: 0.9578
# Epoch 00021: val_FAR did not improve from 0.84960
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2082 - POD: 0.3337 - FAR: 0.7148 - binary_acc: 0.9578 - val_loss: 0.1917 - val_POD: 0.2119 - val_FAR: 0.8674 - val_binary_acc: 0.9666 - lr: 1.0000e-04
# Epoch 22/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2053 - POD: 0.3414 - FAR: 0.7097 - binary_acc: 0.9581
# Epoch 00022: val_FAR did not improve from 0.84960
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2053 - POD: 0.3414 - FAR: 0.7097 - binary_acc: 0.9581 - val_loss: 0.1935 - val_POD: 0.1837 - val_FAR: 0.8537 - val_binary_acc: 0.9707 - lr: 1.0000e-04
# Epoch 23/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2215 - POD: 0.3158 - FAR: 0.7304 - binary_acc: 0.9547
# Epoch 00023: val_FAR improved from 0.84960 to 0.83029, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 104s 143ms/step - loss: 0.2215 - POD: 0.3158 - FAR: 0.7304 - binary_acc: 0.9547 - val_loss: 0.1650 - val_POD: 0.1964 - val_FAR: 0.8303 - val_binary_acc: 0.9728 - lr: 1.0000e-05
# Epoch 24/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2116 - POD: 0.3248 - FAR: 0.7168 - binary_acc: 0.9573
# Epoch 00024: val_FAR improved from 0.83029 to 0.83010, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 143ms/step - loss: 0.2116 - POD: 0.3248 - FAR: 0.7168 - binary_acc: 0.9573 - val_loss: 0.1657 - val_POD: 0.1959 - val_FAR: 0.8301 - val_binary_acc: 0.9727 - lr: 1.0000e-05
# Epoch 25/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2079 - POD: 0.3334 - FAR: 0.7130 - binary_acc: 0.9578
# Epoch 00025: val_FAR improved from 0.83010 to 0.82723, saving model to /content/drive/MyDrive/Lightning/saved models
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Lightning/saved models/assets
# 731/731 [==============================] - 105s 143ms/step - loss: 0.2079 - POD: 0.3334 - FAR: 0.7130 - binary_acc: 0.9578 - val_loss: 0.1666 - val_POD: 0.1979 - val_FAR: 0.8272 - val_binary_acc: 0.9725 - lr: 1.0000e-05
# Epoch 26/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2052 - POD: 0.3401 - FAR: 0.7091 - binary_acc: 0.9582
# Epoch 00026: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2052 - POD: 0.3401 - FAR: 0.7091 - binary_acc: 0.9582 - val_loss: 0.1675 - val_POD: 0.1992 - val_FAR: 0.8300 - val_binary_acc: 0.9724 - lr: 1.0000e-05
# Epoch 27/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2029 - POD: 0.3459 - FAR: 0.7064 - binary_acc: 0.9585
# Epoch 00027: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.2029 - POD: 0.3459 - FAR: 0.7064 - binary_acc: 0.9585 - val_loss: 0.1684 - val_POD: 0.1996 - val_FAR: 0.8298 - val_binary_acc: 0.9723 - lr: 1.0000e-05
# Epoch 28/50
# 731/731 [==============================] - ETA: 0s - loss: 0.2009 - POD: 0.3511 - FAR: 0.7052 - binary_acc: 0.9588
# Epoch 00028: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 93s 127ms/step - loss: 0.2009 - POD: 0.3511 - FAR: 0.7052 - binary_acc: 0.9588 - val_loss: 0.1692 - val_POD: 0.1990 - val_FAR: 0.8280 - val_binary_acc: 0.9724 - lr: 1.0000e-05
# Epoch 29/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1991 - POD: 0.3556 - FAR: 0.7035 - binary_acc: 0.9590
# Epoch 00029: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1991 - POD: 0.3556 - FAR: 0.7035 - binary_acc: 0.9590 - val_loss: 0.1700 - val_POD: 0.1986 - val_FAR: 0.8310 - val_binary_acc: 0.9724 - lr: 1.0000e-05
# Epoch 30/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1974 - POD: 0.3604 - FAR: 0.7010 - binary_acc: 0.9592
# Epoch 00030: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1974 - POD: 0.3604 - FAR: 0.7010 - binary_acc: 0.9592 - val_loss: 0.1708 - val_POD: 0.1979 - val_FAR: 0.8283 - val_binary_acc: 0.9724 - lr: 1.0000e-05
# Epoch 31/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1958 - POD: 0.3648 - FAR: 0.6993 - binary_acc: 0.9594
# Epoch 00031: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1958 - POD: 0.3648 - FAR: 0.6993 - binary_acc: 0.9594 - val_loss: 0.1716 - val_POD: 0.1975 - val_FAR: 0.8283 - val_binary_acc: 0.9725 - lr: 1.0000e-05
# Epoch 32/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1943 - POD: 0.3687 - FAR: 0.6972 - binary_acc: 0.9596
# Epoch 00032: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1943 - POD: 0.3687 - FAR: 0.6972 - binary_acc: 0.9596 - val_loss: 0.1725 - val_POD: 0.1967 - val_FAR: 0.8288 - val_binary_acc: 0.9725 - lr: 1.0000e-05
# Epoch 33/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1928 - POD: 0.3725 - FAR: 0.6961 - binary_acc: 0.9598
# Epoch 00033: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1928 - POD: 0.3725 - FAR: 0.6961 - binary_acc: 0.9598 - val_loss: 0.1733 - val_POD: 0.1966 - val_FAR: 0.8286 - val_binary_acc: 0.9726 - lr: 1.0000e-05
# Epoch 34/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1941 - POD: 0.3724 - FAR: 0.7002 - binary_acc: 0.9597
# Epoch 00034: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1941 - POD: 0.3724 - FAR: 0.7002 - binary_acc: 0.9597 - val_loss: 0.1732 - val_POD: 0.2099 - val_FAR: 0.8317 - val_binary_acc: 0.9712 - lr: 1.0000e-06
# Epoch 35/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1927 - POD: 0.3752 - FAR: 0.6981 - binary_acc: 0.9598
# Epoch 00035: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1927 - POD: 0.3752 - FAR: 0.6981 - binary_acc: 0.9598 - val_loss: 0.1733 - val_POD: 0.2123 - val_FAR: 0.8322 - val_binary_acc: 0.9709 - lr: 1.0000e-06
# Epoch 36/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1921 - POD: 0.3760 - FAR: 0.6965 - binary_acc: 0.9599
# Epoch 00036: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1921 - POD: 0.3760 - FAR: 0.6965 - binary_acc: 0.9599 - val_loss: 0.1734 - val_POD: 0.2140 - val_FAR: 0.8337 - val_binary_acc: 0.9707 - lr: 1.0000e-06
# Epoch 37/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1918 - POD: 0.3764 - FAR: 0.6958 - binary_acc: 0.9600
# Epoch 00037: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1918 - POD: 0.3764 - FAR: 0.6958 - binary_acc: 0.9600 - val_loss: 0.1735 - val_POD: 0.2144 - val_FAR: 0.8345 - val_binary_acc: 0.9706 - lr: 1.0000e-06
# Epoch 38/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1915 - POD: 0.3770 - FAR: 0.6955 - binary_acc: 0.9600
# Epoch 00038: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1915 - POD: 0.3770 - FAR: 0.6955 - binary_acc: 0.9600 - val_loss: 0.1735 - val_POD: 0.2153 - val_FAR: 0.8347 - val_binary_acc: 0.9706 - lr: 1.0000e-06
# Epoch 39/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1912 - POD: 0.3775 - FAR: 0.6951 - binary_acc: 0.9600
# Epoch 00039: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1912 - POD: 0.3775 - FAR: 0.6951 - binary_acc: 0.9600 - val_loss: 0.1736 - val_POD: 0.2154 - val_FAR: 0.8350 - val_binary_acc: 0.9706 - lr: 1.0000e-06
# Epoch 40/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1910 - POD: 0.3780 - FAR: 0.6947 - binary_acc: 0.9601
# Epoch 00040: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1910 - POD: 0.3780 - FAR: 0.6947 - binary_acc: 0.9601 - val_loss: 0.1737 - val_POD: 0.2157 - val_FAR: 0.8348 - val_binary_acc: 0.9706 - lr: 1.0000e-06
# Epoch 41/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1908 - POD: 0.3783 - FAR: 0.6943 - binary_acc: 0.9601
# Epoch 00041: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 93s 127ms/step - loss: 0.1908 - POD: 0.3783 - FAR: 0.6943 - binary_acc: 0.9601 - val_loss: 0.1738 - val_POD: 0.2158 - val_FAR: 0.8355 - val_binary_acc: 0.9705 - lr: 1.0000e-06
# Epoch 42/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1906 - POD: 0.3788 - FAR: 0.6939 - binary_acc: 0.9601
# Epoch 00042: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 126ms/step - loss: 0.1906 - POD: 0.3788 - FAR: 0.6939 - binary_acc: 0.9601 - val_loss: 0.1739 - val_POD: 0.2158 - val_FAR: 0.8356 - val_binary_acc: 0.9705 - lr: 1.0000e-06
# Epoch 43/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1904 - POD: 0.3793 - FAR: 0.6937 - binary_acc: 0.9602
# Epoch 00043: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 125ms/step - loss: 0.1904 - POD: 0.3793 - FAR: 0.6937 - binary_acc: 0.9602 - val_loss: 0.1740 - val_POD: 0.2172 - val_FAR: 0.8356 - val_binary_acc: 0.9705 - lr: 1.0000e-06
# Epoch 44/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1902 - POD: 0.3701 - FAR: 0.6864 - binary_acc: 0.9612
# Epoch 00044: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 125ms/step - loss: 0.1902 - POD: 0.3701 - FAR: 0.6864 - binary_acc: 0.9612 - val_loss: 0.1741 - val_POD: 0.2209 - val_FAR: 0.8384 - val_binary_acc: 0.9700 - lr: 1.0000e-07
# Epoch 45/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1901 - POD: 0.3739 - FAR: 0.6888 - binary_acc: 0.9608
# Epoch 00045: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 125ms/step - loss: 0.1901 - POD: 0.3739 - FAR: 0.6888 - binary_acc: 0.9608 - val_loss: 0.1742 - val_POD: 0.2231 - val_FAR: 0.8402 - val_binary_acc: 0.9697 - lr: 1.0000e-07
# Epoch 46/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1900 - POD: 0.3763 - FAR: 0.6902 - binary_acc: 0.9606
# Epoch 00046: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 91s 125ms/step - loss: 0.1900 - POD: 0.3763 - FAR: 0.6902 - binary_acc: 0.9606 - val_loss: 0.1743 - val_POD: 0.2248 - val_FAR: 0.8412 - val_binary_acc: 0.9694 - lr: 1.0000e-07
# Epoch 47/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1900 - POD: 0.3779 - FAR: 0.6912 - binary_acc: 0.9605
# Epoch 00047: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 92s 125ms/step - loss: 0.1900 - POD: 0.3779 - FAR: 0.6912 - binary_acc: 0.9605 - val_loss: 0.1744 - val_POD: 0.2257 - val_FAR: 0.8420 - val_binary_acc: 0.9693 - lr: 1.0000e-07
# Epoch 48/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1900 - POD: 0.3789 - FAR: 0.6918 - binary_acc: 0.9604
# Epoch 00048: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 91s 125ms/step - loss: 0.1900 - POD: 0.3789 - FAR: 0.6918 - binary_acc: 0.9604 - val_loss: 0.1745 - val_POD: 0.2261 - val_FAR: 0.8423 - val_binary_acc: 0.9692 - lr: 1.0000e-07
# Epoch 49/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1899 - POD: 0.3795 - FAR: 0.6923 - binary_acc: 0.9603
# Epoch 00049: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 91s 125ms/step - loss: 0.1899 - POD: 0.3795 - FAR: 0.6923 - binary_acc: 0.9603 - val_loss: 0.1745 - val_POD: 0.2266 - val_FAR: 0.8426 - val_binary_acc: 0.9691 - lr: 1.0000e-07
# Epoch 50/50
# 731/731 [==============================] - ETA: 0s - loss: 0.1899 - POD: 0.3800 - FAR: 0.6925 - binary_acc: 0.9603
# Epoch 00050: val_FAR did not improve from 0.82723
# 731/731 [==============================] - 91s 125ms/step - loss: 0.1899 - POD: 0.3800 - FAR: 0.6925 - binary_acc: 0.9603 - val_loss: 0.1746 - val_POD: 0.2268 - val_FAR: 0.8429 - val_binary_acc: 0.9691 - lr: 1.0000e-07
